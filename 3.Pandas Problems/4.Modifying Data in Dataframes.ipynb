# %%
import pandas as pd
import os

os.chdir("C:\\Users\\admin\\Desktop\\Impetus\\Programs\\3.Pandas Problems\\Data")

df = pd.read_csv("survey_results_public.csv",index_col = "Respondent")
df1 = pd.read_csv("survey_results_schema.csv",index_col='Column')

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
# changing every name 
df.columns = df.columns.str.lower()
df
# Out:
#                                                    mainbranch hobbyist   age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
#if you want to change specific column name
df.rename(columns={'mainbranch': "Hllo"})
# Out:
#                                                          Hllo hobbyist   age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
#changing data of specific location
df.loc[1,'age'] = 54
#changing data of entire column
df['mainbranch'] = df['mainbranch'].str.upper()
df
# Out:
#                                                    mainbranch hobbyist   age  \
# Respondent
# 1                              I AM A DEVELOPER BY PROFESSION      Yes  54.0
# 2                              I AM A DEVELOPER BY PROFESSION       No   NaN
# 3                                 I CODE PRIMARILY AS A HOBBY      Yes   NaN
# 4                              I AM A DEVELOPER BY PROFESSION      Yes  25.0
# 5           I USED TO BE A DEVELOPER BY PROFESSION, BUT NO...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df['mainbranch'].str.lower()
# Out:
# Respondent
# 1                           i am a developer by profession
# 2                           i am a developer by profession
# 3                              i code primarily as a hobby
# 4                           i am a developer by profession
# 5        i used to be a developer by profession, but no...
#                                ...
# 64858                                                  NaN
# 64867                                                  NaN
# 64898                                                  NaN
# 64925                                                  NaN
# 65112                                                  NaN
# Name: mainbranch, Length: 64461, dtype: object

# %%
#apply on Series
filt = df['mainbranch'].str.contains('DEVELOPER',na=False) 
df = df.loc[filt] #doing this because there are nan values in mainbranch which gives error when we use apply
df['mainbranch'].apply(len)
# Out:
# Respondent
# 1        30
# 2        30
# 4        30
# 5        56
# 6        30
#          ..
# 65632    30
# 65633    56
# 65634    30
# 65635    30
# 65636    30
# Name: mainbranch, Length: 53878, dtype: int64

# %%
#apply on dataframe
df.apply(len)
# Out:
# mainbranch                      53878
# hobbyist                        53878
# age                             53878
# age1stcode                      53878
# compfreq                        53878
# comptotal                       53878
# convertedcomp                   53878
# country                         53878
# currencydesc                    53878
# currencysymbol                  53878
# databasedesirenextyear          53878
# databaseworkedwith              53878
# devtype                         53878
# edlevel                         53878
# employment                      53878
# ethnicity                       53878
# gender                          53878
# jobfactors                      53878
# jobsat                          53878
# jobseek                         53878
# languagedesirenextyear          53878
# languageworkedwith              53878
# misctechdesirenextyear          53878
# misctechworkedwith              53878
# newcollabtoolsdesirenextyear    53878
# ...

# %%
#map
import numpy as np
df['age'].map({np.NaN:20}) #it makes other value nan because we haven't specified
# Out:
# Respondent
# 1         NaN
# 2        20.0
# 4         NaN
# 5         NaN
# 6        20.0
#          ...
# 65632    20.0
# 65633    20.0
# 65634    20.0
# 65635    20.0
# 65636    20.0
# Name: age, Length: 53878, dtype: float64

# %%
#replace
import numpy as np
df['age'].replace({np.NaN:20}) #it leaves the other value
# Out:
# Respondent
# 1        54.0
# 2        20.0
# 4        25.0
# 5        31.0
# 6        20.0
#          ...
# 65632    20.0
# 65633    20.0
# 65634    20.0
# 65635    20.0
# 65636    20.0
# Name: age, Length: 53878, dtype: float64

# %%
del df['age']

# %%
# Out:
#                                                    mainbranch hobbyist  \
# Respondent
# 1                              I AM A DEVELOPER BY PROFESSION      Yes
# 2                              I AM A DEVELOPER BY PROFESSION       No
# 4                              I AM A DEVELOPER BY PROFESSION      Yes
# 5           I USED TO BE A DEVELOPER BY PROFESSION, BUT NO...      Yes
# 6                              I AM A DEVELOPER BY PROFESSION       No
# ...                                                       ...      ...
# 65632                          I AM A DEVELOPER BY PROFESSION      Yes
# 65633       I USED TO BE A DEVELOPER BY PROFESSION, BUT NO...       No
# 65634                          I AM A DEVELOPER BY PROFESSION      Yes
# 65635                          I AM A DEVELOPER BY PROFESSION      Yes
# 65636                          I AM A DEVELOPER BY PROFESSION      Yes
#
#            age1stcode compfreq  comptotal  convertedcomp         country  \
# Respondent
# ...
